# %% [markdown]
# # Formulation of the HFMDCVRP (Multi Depot Heterogeneous Fleet CVRP)

# %% [markdown]
# Packages importation

# %%
import numpy as np
import matplotlib.pyplot as plt
from gurobipy import *
import pandas as pd

# %% [markdown]
# Data importation:

# %%
cmoto = np.loadtxt("distmoto.txt")
cvan = np.loadtxt("distvan.txt")
ccamion = np.loadtxt("distcamion.txt")

# %%
# Number of vehicles
Vehic = 6

# Number of clients
Clients = 12

# Big M
M = 12

# Number of depots
Depots = 2

# %% [markdown]
# Sets
#
# ![imagen.png](attachment:imagen.png)

# %%
N = [i for i in range(Clients+Depots)] # Set of nodes
C = [i for i in range(Depots,Clients+Depots)]
A = [(i,j) for i in N for j in N]
K = [i for i in range(Vehic)]
D = [i for i in range(Depots)]

# %% [markdown]
# Getting the demand of every customer:

# %%
demand = np.loadtxt("demand.txt")
d = {i: demand[i] for i in C}

# %% [markdown]
# Capacity of each depot

# %%
R = [4,4]

# %% [markdown]
# Setting the distance matrix for every vehicle:

# %%
c = np.zeros([Clients+Depots,Clients+Depots,Vehic])
c[:,:,0]=cmoto
c[:,:,1]=cmoto
c[:,:,2]=cvan
c[:,:,3]=cvan
c[:,:,4]=ccamion
c[:,:,5]=ccamion

# %% [markdown]
# Final parameter, the capacity of each vehicle

# %%
capacidad = np.loadtxt("cap.txt")
q = {i: capacidad[i] for i in K}

# %%
# Call the model
m = Model("HFMDVRP")
m.setParam("TimeLimit",60)
# Out:
# Academic license - for non-commercial use only - expires 2021-04-09
# Using license file C:\Users\57316\gurobi.lic
# Changed value of parameter TimeLimit to 60.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf

# %% [markdown]
# Variables:
#
# ![imagen-11.png](attachment:imagen-11.png)
# ![imagen-9.png](attachment:imagen-9.png)

# %%
x = m.addVars(A,K,vtype=GRB.BINARY,name="x")
u = m.addVars(A,K,vtype=GRB.CONTINUOUS,lb=0,name="u")
w = m.addVars(D,K,vtype=GRB.BINARY,name="w")
z = m.addVars(C,K,vtype=GRB.BINARY,name="z")

# %% [markdown]
# Objective function
#
# ![imagen.png](attachment:imagen.png)

# %%
m.modelSense = GRB.MINIMIZE
m.setObjective(quicksum(c[i,j,k]*x[i,j,k] for i,j in A for k in K))

# %% [markdown]
# # Constraints
#
# Every client must be visited once
#
# ![imagen-2.png](attachment:imagen-2.png)

# %%
m.addConstrs(quicksum(z[i,k] for k in K)==1 for i in C);

# %% [markdown]
# The demand served by a vehicle must be less than its capacity
#
# ![imagen.png](attachment:imagen.png)

# %%
m.addConstrs(quicksum(d[i]*x[i,j,k] for i in C for j in N)<=q[k] for k in K);

# %% [markdown]
# Vehicles must start the route at the depot assigned to it
#
# ![imagen.png](attachment:imagen.png)

# %%
m.addConstrs(quicksum(x[h,j,k] for j in N)==w[h,k] for k in K for h in D);
m.addConstrs(quicksum(x[i,h,k] for i in N)==w[h,k] for k in K for h in D);

# %% [markdown]
# Flow constraint
#
# ![imagen.png](attachment:imagen.png)

# %%
m.addConstrs(quicksum(x[i,h,k] for i in N)-quicksum(x[h,j,k] for j in N)==0 for k in K for h in C);

# %% [markdown]
# Load constraints
#
# ![imagen-6.png](attachment:imagen-6.png)

# %%
m.addConstrs(quicksum(u[h,j,k] for h in D for j in C) == 0 for k in K);
m.addConstrs(quicksum(u[i,h,k] for i in N) - quicksum(u[h,j,k] for j in N) + z[h,k] == 0 for h in C for k in K);

# %% [markdown]
# Depot capacity
#
# ![imagen-3.png](attachment:imagen-3.png)

# %%
m.addConstrs(quicksum(w[h,k] for k in K) <= R[h] for h in D);

# %% [markdown]
# Upper bound of variable f
#
# ![imagen-2.png](attachment:imagen-2.png)

# %%
m.addConstrs(u[i,j,k] <= M*x[i,j,k] for i in N for j in N for k in K);

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1370 rows, 2436 columns and 7764 nonzeros
# Model fingerprint: 0x3e609361
# Variable types: 1176 continuous, 1260 integer (1260 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 254 rows and 340 columns
# Presolve time: 0.05s
# Presolved: 1116 rows, 2096 columns, 6844 nonzeros
# Variable types: 928 continuous, 1168 integer (1168 binary)
#
# Root relaxation: objective 1.473393e+03, 1456 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1473.39333    0   27          - 1473.39333      -     -    0s
#      0     0 1586.43128    0   42          - 1586.43128      -     -    0s
#      0     0 1612.93261    0   34          - 1612.93261      -     -    0s
#      0     0 1626.79556    0   62          - 1626.79556      -     -    0s
#      0     0 1627.33487    0   39          - 1627.33487      -     -    0s
#      0     0 1627.33487    0   66          - 1627.33487      -     -    0s
#      0     0 2130.35353    0   85          - 2130.35353      -     -    0s
#      0     0 2317.78868    0   47          - 2317.78868      -     -    0s
#      0     0 2329.19088    0   49          - 2329.19088      -     -    0s
#      0     0 2329.19088    0   49          - 2329.19088      -     -    0s
#      0     0 2641.05014    0   99          - 2641.05014      -     -    0s
#      0     0 2699.15001    0   80          - 2699.15001      -     -    0s
#      0     0 2729.71514    0   90          - 2729.71514      -     -    0s
#      0     0 2730.46609    0   89          - 2730.46609      -     -    0s
#      0     0 2730.96686    0   97          - 2730.96686      -     -    0s
#      0     0 3154.79623    0  125          - 3154.79623      -     -    0s
#      0     0 3157.55720    0  123          - 3157.55720      -     -    0s
#      0     0 3157.63872    0  126          - 3157.63872      -     -    0s
#      0     0 3282.25614    0  145          - 3282.25614      -     -    0s
# H    0     0                    10036.450000 3282.25614  67.3%     -    0s
# H    0     0                    9872.4700000 3282.25614  66.8%     -    0s
# H    0     0                    9830.1100000 3282.25614  66.6%     -    0s
#      0     0 3318.45444    0  126 9830.11000 3318.45444  66.2%     -    0s
#      0     0 3322.44875    0  137 9830.11000 3322.44875  66.2%     -    0s
#      0     0 3322.47652    0  138 9830.11000 3322.47652  66.2%     -    0s
# H    0     0                    9826.2700000 3322.47652  66.2%     -    1s
# H    0     0                    9820.1500000 3322.47652  66.2%     -    1s
#      0     0 3475.03069    0  181 9820.15000 3475.03069  64.6%     -    1s
#      0     0 3486.26641    0  188 9820.15000 3486.26641  64.5%     -    1s
#      0     0 3488.96386    0  190 9820.15000 3488.96386  64.5%     -    1s
#      0     0 3490.06957    0  200 9820.15000 3490.06957  64.5%     -    1s
# H    0     0                    9692.5700000 3490.06957  64.0%     -    1s
#      0     0 3502.42850    0  152 9692.57000 3502.42850  63.9%     -    1s
#      0     0 3505.80560    0  156 9692.57000 3505.80560  63.8%     -    1s
#      0     0 3506.01792    0  165 9692.57000 3506.01792  63.8%     -    1s
# H    0     0                    9692.1300000 3506.01792  63.8%     -    1s
#      0     0 3509.92765    0  177 9692.13000 3509.92765  63.8%     -    1s
#      0     0 3509.92765    0  177 9692.13000 3509.92765  63.8%     -    1s
#      0     2 3511.17655    0  176 9692.13000 3511.17655  63.8%     -    1s
# H  416   376                    9691.3800000 4760.87942  50.9%  76.4    3s
# H  417   358                    9071.0500000 4760.87942  47.5%  76.5    3s
# H  709   514                    8504.7900000 4788.82708  43.7%  83.3    4s
# H  996   653                    8500.1800000 4808.42347  43.4%  97.3    5s
#   1139   744 5802.90720   19   94 8500.18000 4808.42347  43.4%   126   10s
# H 1700   806                    8497.1700000 5316.06309  37.4%   132   12s
# * 1763   800              32    8487.0600000 5316.06309  37.4%   131   12s
# H 2679   816                    8480.2700000 7070.18097  16.6%   122   14s
#   2936   846     cutoff   29      8480.27000 7119.84200  16.0%   120   16s
# * 3325   926              33    8458.9800000 7161.04617  15.3%   120   17s
# * 3328   868              32    8444.2700000 7161.04617  15.2%   120   17s
# H 3530   912                    8436.2500000 7161.04617  15.1%   118   17s
# * 4707  1142              35    8422.8000000 8193.36243  2.72%   111   18s
# H 5676  1545                    8421.3000000 8263.37330  1.88%   101   19s
#   5929  1682 8402.90974   37   56 8421.30000 8269.32281  1.80%  98.8   20s
# * 6888  1925              32    8411.6400000 8281.88825  1.54%  92.0   20s
# H10353  2809                    8406.4300000 8301.39891  1.25%  77.0   23s
# *10356  2766              30    8403.4800000 8301.39891  1.21%  77.0   23s
# *11710  2936              34    8399.0100000 8306.61975  1.10%  73.3   24s
# *11712  2895              34    8396.6400000 8306.61975  1.07%  73.3   24s
#  12882  3068 8326.30277   32   35 8396.64000 8311.26014  1.02%  71.4   25s
# H16189  2903                    8381.1100000 8322.27383  0.70%  66.8   27s
#  20922  2285     cutoff   33      8381.11000 8338.85589  0.50%  62.9   30s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 70
#   MIR: 69
#   StrongCG: 6
#   Flow cover: 283
#   Inf proof: 39
#   Zero half: 1
#   Network: 130
#
# Explored 26912 nodes (1549666 simplex iterations) in 33.16 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 8381.11 8396.64 8399.01 ... 8444.27
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.381110000000e+03, best bound 8.381110000000e+03, gap 0.0000%

# %%
m.printAttr("X")
# Out:
#     Variable            X
# -------------------------
#     x[0,0,1]            1
#     x[0,0,2]            1
#     x[0,0,4]            1
#     x[0,8,5]            1
#     x[1,1,1]            1
#     x[1,1,4]            1
#    x[1,11,3]            1
#    x[1,12,0]            1
#     x[2,3,5]            1
#     x[3,4,5]            1
#     x[4,0,5]            1
#     x[5,7,3]            1
#     x[6,2,5]            1
#     x[7,1,3]            1
#     x[8,6,5]            1
#     x[9,5,3]            1
#    x[10,1,0]            1
#    x[11,9,3]            1
#   x[12,13,0]            1
#   x[13,10,0]            1
#     f[2,3,5]           16
#     f[3,4,5]           21
#     f[4,0,5]           27
#     f[5,7,3]           15
#     f[6,2,5]            9
#     f[7,1,3]           20
#     f[8,6,5]            4
#     f[9,5,3]           11
#    f[10,1,0]           12
#    f[11,9,3]            6
#   f[12,13,0]            4
#   f[13,10,0]            7
#       w[0,1]            1
#       w[0,2]            1
#       w[0,4]            1
#       w[0,5]            1
#       w[1,0]            1
#       w[1,1]            1
#       w[1,3]            1
#       w[1,4]            1
#       z[2,5]            1
#       z[3,5]            1
#       z[4,5]            1
#       z[5,3]            1
#       z[6,5]            1
#       z[7,3]            1
#       z[8,5]            1
#       z[9,3]            1
#      z[10,0]            1
#      z[11,3]            1
#      z[12,0]            1
#      z[13,0]            1
